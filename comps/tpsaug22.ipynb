# %% [markdown]
# load useful libraries

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# load train and test dataframes

# %%
train_df = pd.read_csv('data/train.csv', index_col='id')
test_df = pd.read_csv('data/test.csv', index_col='id')

# %% [markdown]
# see that some types are objects:

# %%
train_df.dtypes
# Out:
# product_code       object
# loading           float64
# attribute_0        object
# attribute_1        object
# attribute_2         int64
# attribute_3         int64
# measurement_0       int64
# measurement_1       int64
# measurement_2       int64
# measurement_3     float64
# measurement_4     float64
# measurement_5     float64
# measurement_6     float64
# measurement_7     float64
# measurement_8     float64
# measurement_9     float64
# measurement_10    float64
# measurement_11    float64
# measurement_12    float64
# measurement_13    float64
# measurement_14    float64
# measurement_15    float64
# measurement_16    float64
# measurement_17    float64
# failure             int64
# dtype: object

# %% [markdown]
# See `produt_code` has no overlap between test and train, and hence drop column.
#
# Overlab between `attribute_0` and `attribute_1` is not full, so we drop that too.

# %%
uniques = lambda df: list(map(lambda i: pd.unique(df[df.columns[i]]), [0, 2, 3]))
uniques(train_df), uniques(test_df)
# Out:
# ([array(['A', 'B', 'C', 'D', 'E'], dtype=object),
#   array(['material_7', 'material_5'], dtype=object),
#   array(['material_8', 'material_5', 'material_6'], dtype=object)],
#  [array(['F', 'G', 'H', 'I'], dtype=object),
#   array(['material_5', 'material_7'], dtype=object),
#   array(['material_6', 'material_7', 'material_5'], dtype=object)])

# %%
dropped_train_df = train_df.drop(train_df.columns[[0, 3]], axis=1)
dropped_test_df = test_df.drop(test_df.columns[[0, 3]], axis=1)

# %%
pd.get_dummies(dropped_train_df)
# dropped_train_df
# Out:
#        loading  attribute_2  attribute_3  measurement_0  measurement_1  \
# id
# 0        80.10            9            5              7              8
# 1        84.89            9            5             14              3
# 2        82.43            9            5             12              1
# 3       101.07            9            5             13              2
# 4       188.06            9            5              9              2
# ...        ...          ...          ...            ...            ...
# 26565   158.95            6            9              6             16
# 26566   146.02            6            9             10             12
# 26567   115.62            6            9              1             10
# 26568   106.38            6            9              2              9
# 26569   131.20            6            9              6             19
#
#        measurement_2  measurement_3  measurement_4  measurement_5  \
# id
# ...
